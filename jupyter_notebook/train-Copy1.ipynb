# %% [markdown]
# # Train and Predict
# Train and evaluate model
# - <a href='#1'>1. lightgbm</a>
# - <a href='#2'>2. task2</a>
# - <a href='#3'>3. ensemble</a>

# %%
import sys
import os
import gc
from time import time
from datetime import timedelta, datetime
import base64

import pandas as pd
from IPython.core.display import display, HTML
import numpy as np
from IPython.core.interactiveshell import InteractiveShell
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import lightgbm as lgb
from sklearn import metrics

sys.path.append('../')
import conf
from mlpipeline import (
    feature_engineering,
    train,
    predict,
)
from utils import (
    check_columns,
    check_nan_value,
    #     correct_colum_type,
    decrypt_model,
    plot_dist_of_cols,
)

# %%
# global settings
InteractiveShell.ast_node_interactivity = "all"
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns',1000)
pd.set_option('display.width',100)
sns.set(rc={'figure.figsize':(20,10)})
os.environ["CUDA_VISIBLE_DEVICES"] = "2"

# %%
# global variables
DEFAULT_MISSING_FLOAT = 0
FAULT_TAG = 1

# %%
# notebook settings
# %load_ext autoreload
# %autoreload 2

# %%
# functions
def __dummy():
    pass

# %% [markdown]
# ### <a id='1'> 1.lightgbm</a>

# %%
! du -sh ../data/*
# Out:
# 4.3M	../data/chunk_data_for_test.h5
# 4.2G	../data/data_2017_all.h5
# 2.3G	../data/data_2017_tag_flag.h5
# 2.5G	../data/data_2017_tag_flag_raw.h5
# 20M	../data/data_201808_test.h5
# 41M	../data/data_201808_test_all.h5
# 24M	../data/data_201808_test_raw.h5
# 6.9G	../data/data_2018_all.h5
# 3.9G	../data/data_2018_tag_flag.h5
# 4.2G	../data/data_2018_tag_flag_raw.h5
# 36K	../data/disk_sample_fault_tag.csv
# 1.2G	../data/disk_sample_smart_log_201707.csv
# 228M	../data/disk_sample_smart_log_201707_norm.csv
# 233M	../data/disk_sample_smart_log_201707_raw.csv
# 2.2G	../data/disk_sample_smart_log_201708.csv
# 446M	../data/disk_sample_smart_log_201708_norm.csv
# 460M	../data/disk_sample_smart_log_201708_raw.csv
# 2.2G	../data/disk_sample_smart_log_201709.csv
# 450M	../data/disk_sample_smart_log_201709_norm.csv
# 468M	../data/disk_sample_smart_log_201709_raw.csv
# 2.5G	../data/disk_sample_smart_log_201710.csv
# 507M	../data/disk_sample_smart_log_201710_norm.csv
# 530M	../data/disk_sample_smart_log_201710_raw.csv
# 2.6G	../data/disk_sample_smart_log_201711.csv
# 523M	../data/disk_sample_smart_log_201711_norm.csv
# 551M	../data/disk_sample_smart_log_201711_raw.csv
# 2.9G	../data/disk_sample_smart_log_201712.csv
# 590M	../data/disk_sample_smart_log_201712_norm.csv
# 625M	../data/disk_sample_smart_log_201712_raw.csv
# 3.2G	../data/disk_sample_smart_log_201801.csv
# 637M	../data/disk_sample_smart_log_201801_norm.csv
# 677M	../data/disk_sample_smart_log_201801_raw.csv
# 2.9G	../data/disk_sample_smart_log_201802.csv
# 588M	../data/disk_sample_smart_log_201802_norm.csv
# 627M	../data/disk_sample_smart_log_201802_raw.csv
# 3.3G	../data/disk_sample_smart_log_201803.csv
# 658M	../data/disk_sample_smart_log_201803_norm.csv
# 703M	../data/disk_sample_smart_log_201803_raw.csv
# 3.2G	../data/disk_sample_smart_log_201804.csv
# 644M	../data/disk_sample_smart_log_201804_norm.csv
# 652M	../data/disk_sample_smart_log_201804_norm_tag.csv
# 689M	../data/disk_sample_smart_log_201804_raw.csv
# 3.3G	../data/disk_sample_smart_log_201805.csv
# 670M	../data/disk_sample_smart_log_201805_norm.csv
# 679M	../data/disk_sample_smart_log_201805_norm_tag.csv
# 720M	../data/disk_sample_smart_log_201805_raw.csv
# 3.3G	../data/disk_sample_smart_log_201806.csv
# 671M	../data/disk_sample_smart_log_201806_norm.csv
# 680M	../data/disk_sample_smart_log_201806_norm_tag.csv
# 724M	../data/disk_sample_smart_log_201806_raw.csv
# 3.5G	../data/disk_sample_smart_log_201807.csv
# 703M	../data/disk_sample_smart_log_201807_norm.csv
# 761M	../data/disk_sample_smart_log_201807_raw.csv
# 125M	../data/disk_sample_smart_log_test_a.csv
# 25M	../data/disk_sample_smart_log_test_a_norm.csv
# 25M	../data/disk_sample_smart_log_test_a_raw.csv
# 1.9M	../data/pytables-nv6bgpi1.tmp
# 85M	../data/test_fe_df_02_01_raw.h5
# 40M	../data/test_fe_df_03_01.h5
# 211M	../data/test_fe_df_03_01_raw.h5
# 6.5G	../data/train_fe_df_02_01_raw.h5
# 2.5G	../data/train_fe_df_03_01.h5
# 16G	../data/train_fe_df_03_01_raw.h5
# 2.9G	../data/zip

# %%
# feature engineering
params = {
    'train_filename':'data_2018_tag_flag_raw.h5',  # train file we want to load
    'test_filename': 'data_201808_test_raw.h5',
    'train_fe_save_filename':'train_fe_df_02_01_raw.h5',  # naming the train fe by the start date of train
    'test_fe_save_filename': 'test_fe_df_02_01_raw.h5',  # same as train fe
    'is_sampling': False,
    'sample_validset': False,  # whether do sampling for valid set and train set at the same time
    'train_start_date': '2018-02-01',
    'train_end_date': '2018-06-30',  # include validation data duration
    'valid_start_date': '2018-06-01',  # for judge the val set from train set in sampling process
    'valid_end_date': '2018-06-30',
    'use_model_one': True,
    'num_processes': 14,
}

train_fe_df, test_fe_df = feature_engineering(**params)
# Out:
# 2020-03-02 21:55:04,628 - mlpipeline.feature_engineering - INFO - feature_engineering开始
# 2020-03-02 21:55:04,630 - mlpipeline.feature_engineering - INFO - _load_dataset_by_filename开始
# 2020-03-02 21:55:04,633 - mlpipeline.feature_engineering - INFO - 加载训练数据集: ../data/data_2018_tag_flag_raw.h5
# 2020-03-02 21:58:17,895 - mlpipeline.feature_engineering - INFO - 加载训练数据集完成,共用时: 0:03:13
# 2020-03-02 21:58:17,899 - mlpipeline.feature_engineering - INFO - 加载测试数据集: ../data/data_201808_test_raw.h5
# 2020-03-02 21:58:19,920 - mlpipeline.feature_engineering - INFO - 加载测试数据集完成,共用时: 0:00:02
# 2020-03-02 21:58:19,922 - mlpipeline.feature_engineering - INFO - _load_dataset_by_filename已完成，共用时0:03:15
# 2020-03-02 21:58:19,923 - mlpipeline.feature_engineering - INFO - _data_preprocess开始
# 2020-03-02 21:58:34,833 - utils.utils - INFO - correct_column_type开始
# 2020-03-02 21:58:42,393 - utils.utils - INFO - col_types: serial_number            object
# manufacturer             object
# model                      int8
# dt               datetime64[ns]
# smart_1raw              float32
# smart_3raw              float32
# smart_4raw              float32
# smart_5raw              float32
# smart_7raw              float32
# smart_9raw              float32
# smart_10raw             float32
# smart_12raw             float32
# smart_184raw            float32
# smart_187raw            float32
# smart_188raw            float32
# smart_189raw            float32
# smart_190raw            float32
# smart_191raw            float32
# smart_192raw            float32
# smart_193raw            float32
# smart_194raw            float32
# smart_195raw            float32
# smart_197raw            float32
# smart_198raw            float32
# smart_199raw            float32
# tag                        int8
# flag                       int8
# 30_day                     int8
# dtype: object
# 2020-03-02 21:58:42,396 - utils.utils - INFO - correct_column_type已完成，共用时0:00:07
# 2020-03-02 21:58:42,397 - utils.utils - INFO - correct_column_type开始
# 2020-03-02 21:58:42,562 - utils.utils - INFO - col_types: serial_number            object
# manufacturer             object
# model                      int8
# dt               datetime64[ns]
# smart_1raw              float32
# smart_3raw              float32
# smart_4raw              float32
# smart_5raw              float32
# smart_7raw              float32
# smart_9raw              float32
# smart_10raw             float32
# smart_12raw             float32
# smart_184raw            float32
# smart_187raw            float32
# smart_188raw            float32
# smart_189raw            float32
# smart_190raw            float32
# smart_191raw            float32
# smart_192raw            float32
# smart_193raw            float32
# smart_194raw            float32
# smart_195raw            float32
# smart_197raw            float32
# smart_198raw            float32
# smart_199raw            float32
# dtype: object
# 2020-03-02 21:58:42,563 - utils.utils - INFO - correct_column_type已完成，共用时0:00:00
# 2020-03-02 21:58:53,478 - utils.utils - INFO - remove_cont_cols_with_unique_value开始
# 2020-03-02 21:58:57,421 - utils.utils - INFO - train: smart_1raw - 9804705
# 2020-03-02 21:58:57,422 - utils.utils - INFO - test: smart_1raw - 153600
# 2020-03-02 21:58:57,607 - utils.utils - INFO - train: smart_3raw - 2
# 2020-03-02 21:58:57,611 - utils.utils - INFO - test: smart_3raw - 1
# 2020-03-02 21:58:57,792 - utils.utils - INFO - train: smart_4raw - 1144
# 2020-03-02 21:58:57,793 - utils.utils - INFO - test: smart_4raw - 276
# 2020-03-02 21:58:57,964 - utils.utils - INFO - train: smart_5raw - 2132
# 2020-03-02 21:58:57,966 - utils.utils - INFO - test: smart_5raw - 399
# 2020-03-02 21:59:02,364 - utils.utils - INFO - train: smart_7raw - 10990817
# 2020-03-02 21:59:02,369 - utils.utils - INFO - test: smart_7raw - 174576
# 2020-03-02 21:59:02,648 - utils.utils - INFO - train: smart_9raw - 41258
# 2020-03-02 21:59:02,649 - utils.utils - INFO - test: smart_9raw - 23444
# 2020-03-02 21:59:02,791 - utils.utils - INFO - train: smart_10raw - 2
# 2020-03-02 21:59:02,792 - utils.utils - INFO - test: smart_10raw - 2
# 2020-03-02 21:59:02,985 - utils.utils - INFO - train: smart_12raw - 1144
# 2020-03-02 21:59:02,987 - utils.utils - INFO - test: smart_12raw - 259
# 2020-03-02 21:59:03,157 - utils.utils - INFO - train: smart_184raw - 309
# 2020-03-02 21:59:03,159 - utils.utils - INFO - test: smart_184raw - 30
# 2020-03-02 21:59:03,306 - utils.utils - INFO - train: smart_187raw - 105
# 2020-03-02 21:59:03,308 - utils.utils - INFO - test: smart_187raw - 31
# 2020-03-02 21:59:03,456 - utils.utils - INFO - train: smart_188raw - 315
# 2020-03-02 21:59:03,457 - utils.utils - INFO - test: smart_188raw - 58
# 2020-03-02 21:59:03,682 - utils.utils - INFO - train: smart_189raw - 1409
# 2020-03-02 21:59:03,683 - utils.utils - INFO - test: smart_189raw - 245
# 2020-03-02 21:59:03,834 - utils.utils - INFO - train: smart_190raw - 76
# 2020-03-02 21:59:03,836 - utils.utils - INFO - test: smart_190raw - 47
# 2020-03-02 21:59:03,969 - utils.utils - INFO - train: smart_191raw - 2
# 2020-03-02 21:59:03,971 - utils.utils - INFO - test: smart_191raw - 1
# 2020-03-02 21:59:04,148 - utils.utils - INFO - train: smart_192raw - 1123
# 2020-03-02 21:59:04,149 - utils.utils - INFO - test: smart_192raw - 258
# 2020-03-02 21:59:04,350 - utils.utils - INFO - train: smart_193raw - 22455
# 2020-03-02 21:59:04,351 - utils.utils - INFO - test: smart_193raw - 4320
# 2020-03-02 21:59:04,496 - utils.utils - INFO - train: smart_194raw - 76
# 2020-03-02 21:59:04,498 - utils.utils - INFO - test: smart_194raw - 48
# 2020-03-02 21:59:08,558 - utils.utils - INFO - train: smart_195raw - 9804677
# 2020-03-02 21:59:08,560 - utils.utils - INFO - test: smart_195raw - 153600
# 2020-03-02 21:59:08,745 - utils.utils - INFO - train: smart_197raw - 458
# 2020-03-02 21:59:08,749 - utils.utils - INFO - test: smart_197raw - 134
# 2020-03-02 21:59:08,878 - utils.utils - INFO - train: smart_198raw - 457
# 2020-03-02 21:59:08,880 - utils.utils - INFO - test: smart_198raw - 134
# 2020-03-02 21:59:09,043 - utils.utils - INFO - train: smart_199raw - 4409
# 2020-03-02 21:59:09,045 - utils.utils - INFO - test: smart_199raw - 129
# 2020-03-02 21:59:09,046 - utils.utils - INFO - drop cols: ['smart_3raw', 'smart_10raw', 'smart_191raw']
# 2020-03-02 21:59:09,046 - utils.utils - INFO - remove_cont_cols_with_unique_value已完成，共用时0:00:16
# 2020-03-02 21:59:12,080 - mlpipeline.feature_engineering - INFO - _data_preprocess已完成，共用时0:00:52
# 2020-03-02 21:59:15,169 - mlpipeline.feature_engineering - INFO - _sliding_window开始
# 100%|██████████| 98690/98690 [24:28<00:00, 67.19it/s]
# 2020-03-02 22:29:08,525 - mlpipeline.feature_engineering - INFO - 构造滑窗特征后，当前维度:77
# 2020-03-02 22:29:13,731 - mlpipeline.feature_engineering - INFO - _sliding_window已完成，共用时0:29:59
# 2020-03-02 22:29:14,218 - utils.utils - INFO - check_nan_value开始
# 2020-03-02 22:29:14,259 - utils.utils - INFO - smart_1raw_min_30 - 0.0
# 2020-03-02 22:29:14,299 - utils.utils - INFO - smart_4raw_min_30 - 0.0
# 2020-03-02 22:29:14,340 - utils.utils - INFO - smart_5raw_min_30 - 0.0
# 2020-03-02 22:29:14,379 - utils.utils - INFO - smart_7raw_min_30 - 0.0
# 2020-03-02 22:29:14,421 - utils.utils - INFO - smart_9raw_min_30 - 0.0
# 2020-03-02 22:29:14,459 - utils.utils - INFO - smart_12raw_min_30 - 0.0
# 2020-03-02 22:29:14,499 - utils.utils - INFO - smart_184raw_min_30 - 0.0
# 2020-03-02 22:29:14,537 - utils.utils - INFO - smart_187raw_min_30 - 0.0
# 2020-03-02 22:29:14,576 - utils.utils - INFO - smart_188raw_min_30 - 0.0
# 2020-03-02 22:29:14,621 - utils.utils - INFO - smart_189raw_min_30 - 0.0
# 2020-03-02 22:29:14,659 - utils.utils - INFO - smart_190raw_min_30 - 0.0
# 2020-03-02 22:29:14,699 - utils.utils - INFO - smart_192raw_min_30 - 0.0
# 2020-03-02 22:29:14,741 - utils.utils - INFO - smart_193raw_min_30 - 0.0
# 2020-03-02 22:29:14,781 - utils.utils - INFO - smart_194raw_min_30 - 0.0
# 2020-03-02 22:29:14,820 - utils.utils - INFO - smart_195raw_min_30 - 0.0
# 2020-03-02 22:29:14,858 - utils.utils - INFO - smart_197raw_min_30 - 0.0
# 2020-03-02 22:29:14,897 - utils.utils - INFO - smart_198raw_min_30 - 0.0
# 2020-03-02 22:29:14,934 - utils.utils - INFO - smart_199raw_min_30 - 0.0
# 2020-03-02 22:29:14,975 - utils.utils - INFO - smart_1raw_max_30 - 0.0
# 2020-03-02 22:29:15,014 - utils.utils - INFO - smart_4raw_max_30 - 0.0
# 2020-03-02 22:29:15,051 - utils.utils - INFO - smart_5raw_max_30 - 0.0
# 2020-03-02 22:29:15,088 - utils.utils - INFO - smart_7raw_max_30 - 0.0
# 2020-03-02 22:29:15,123 - utils.utils - INFO - smart_9raw_max_30 - 0.0
# 2020-03-02 22:29:15,160 - utils.utils - INFO - smart_12raw_max_30 - 0.0
# 2020-03-02 22:29:15,202 - utils.utils - INFO - smart_184raw_max_30 - 0.0
# 2020-03-02 22:29:15,240 - utils.utils - INFO - smart_187raw_max_30 - 0.0
# 2020-03-02 22:29:15,281 - utils.utils - INFO - smart_188raw_max_30 - 0.0
# 2020-03-02 22:29:15,322 - utils.utils - INFO - smart_189raw_max_30 - 0.0
# 2020-03-02 22:29:15,363 - utils.utils - INFO - smart_190raw_max_30 - 0.0
# 2020-03-02 22:29:15,401 - utils.utils - INFO - smart_192raw_max_30 - 0.0
# 2020-03-02 22:29:15,454 - utils.utils - INFO - smart_193raw_max_30 - 0.0
# 2020-03-02 22:29:15,520 - utils.utils - INFO - smart_194raw_max_30 - 0.0
# 2020-03-02 22:29:15,577 - utils.utils - INFO - smart_195raw_max_30 - 0.0
# 2020-03-02 22:29:15,626 - utils.utils - INFO - smart_197raw_max_30 - 0.0
# 2020-03-02 22:29:15,673 - utils.utils - INFO - smart_198raw_max_30 - 0.0
# 2020-03-02 22:29:15,724 - utils.utils - INFO - smart_199raw_max_30 - 0.0
# 2020-03-02 22:29:15,763 - utils.utils - INFO - smart_1raw_diff_for_last_period_30 - 0.06
# 2020-03-02 22:29:15,810 - utils.utils - INFO - smart_4raw_diff_for_last_period_30 - 0.06
# 2020-03-02 22:29:15,868 - utils.utils - INFO - smart_5raw_diff_for_last_period_30 - 0.06
# 2020-03-02 22:29:15,911 - utils.utils - INFO - smart_7raw_diff_for_last_period_30 - 0.06
# 2020-03-02 22:29:15,944 - utils.utils - INFO - smart_9raw_diff_for_last_period_30 - 0.06
# 2020-03-02 22:29:15,976 - utils.utils - INFO - smart_12raw_diff_for_last_period_30 - 0.06
# 2020-03-02 22:29:16,011 - utils.utils - INFO - smart_184raw_diff_for_last_period_30 - 0.06
# 2020-03-02 22:29:16,042 - utils.utils - INFO - smart_187raw_diff_for_last_period_30 - 0.06
# 2020-03-02 22:29:16,073 - utils.utils - INFO - smart_188raw_diff_for_last_period_30 - 0.06
# 2020-03-02 22:29:16,107 - utils.utils - INFO - smart_189raw_diff_for_last_period_30 - 0.06
# 2020-03-02 22:29:16,161 - utils.utils - INFO - smart_190raw_diff_for_last_period_30 - 0.06
# 2020-03-02 22:29:16,219 - utils.utils - INFO - smart_192raw_diff_for_last_period_30 - 0.06
# 2020-03-02 22:29:16,250 - utils.utils - INFO - smart_193raw_diff_for_last_period_30 - 0.06
# 2020-03-02 22:29:16,280 - utils.utils - INFO - smart_194raw_diff_for_last_period_30 - 0.06
# 2020-03-02 22:29:16,311 - utils.utils - INFO - smart_195raw_diff_for_last_period_30 - 0.06
# 2020-03-02 22:29:16,345 - utils.utils - INFO - smart_197raw_diff_for_last_period_30 - 0.06
# 2020-03-02 22:29:16,376 - utils.utils - INFO - smart_198raw_diff_for_last_period_30 - 0.06
# 2020-03-02 22:29:16,407 - utils.utils - INFO - smart_199raw_diff_for_last_period_30 - 0.06
# 2020-03-02 22:29:16,432 - utils.utils - INFO - operation_duration - 0.0
# 2020-03-02 22:29:16,464 - utils.utils - INFO - smart_1raw - 0.0
# 2020-03-02 22:29:16,495 - utils.utils - INFO - smart_4raw - 0.0
# 2020-03-02 22:29:16,532 - utils.utils - INFO - smart_5raw - 0.0
# 2020-03-02 22:29:16,564 - utils.utils - INFO - smart_7raw - 0.0
# 2020-03-02 22:29:16,596 - utils.utils - INFO - smart_9raw - 0.0
# 2020-03-02 22:29:16,627 - utils.utils - INFO - smart_12raw - 0.0
# 2020-03-02 22:29:16,657 - utils.utils - INFO - smart_184raw - 0.0
# 2020-03-02 22:29:16,688 - utils.utils - INFO - smart_187raw - 0.0
# 2020-03-02 22:29:16,720 - utils.utils - INFO - smart_188raw - 0.0
# 2020-03-02 22:29:16,751 - utils.utils - INFO - smart_189raw - 0.0
# 2020-03-02 22:29:16,781 - utils.utils - INFO - smart_190raw - 0.0
# 2020-03-02 22:29:16,812 - utils.utils - INFO - smart_192raw - 0.0
# 2020-03-02 22:29:16,843 - utils.utils - INFO - smart_193raw - 0.0
# 2020-03-02 22:29:16,883 - utils.utils - INFO - smart_194raw - 0.0
# 2020-03-02 22:29:16,918 - utils.utils - INFO - smart_195raw - 0.0
# 2020-03-02 22:29:16,951 - utils.utils - INFO - smart_197raw - 0.0
# 2020-03-02 22:29:16,982 - utils.utils - INFO - smart_198raw - 0.0
# 2020-03-02 22:29:17,014 - utils.utils - INFO - smart_199raw - 0.0
# 2020-03-02 22:29:18,716 - utils.utils - INFO - manufacturer - 0.0
# 2020-03-02 22:29:18,744 - utils.utils - INFO - model - 0.0
# 2020-03-02 22:29:21,112 - utils.utils - INFO - serial_number - 0.0
# 2020-03-02 22:29:21,154 - utils.utils - INFO - dt - 0.0
# 2020-03-02 22:29:21,155 - utils.utils - INFO - check_nan_value已完成，共用时0:00:07
# 2020-03-02 22:29:27,475 - mlpipeline.feature_engineering - INFO - _fill_cont_cols_na_value_by_mean开始

# %%
# eval
model_params = {
    "objective": "binary",
    "boosting": 'gbdt',
    "learning_rate": 0.001,
    "scale_pos_weight": 25,
    #                 "is_unbalance": True,
    "num_leaves": 32,
    "metric": ["auc"],
    "subsample": 0.8,
    "colsample_bytree": 0.6,
    "num_threads": 10,
    "lambda_l2": 0.8,
    "lambda_l1": 0.8,
    "random_state": 2019,
    "min_data_in_leaf": 80,
    "num_boost_round": 1000,
    "device": 'cpu',
}  # 'cpu','gpu'
#                 "gpu_device_id":'2
#                 "max_bin":255}

params = {
    'model_params': model_params,
    'model_name': 'lgb',
    'train_fe_filename': 'train_fe_df_02_01_raw.h5',
    'is_eval': True,
    "is_standard": True,  # whether using sklearn-standard
    'train_start_date': '2018-02-01',
    'train_end_date': '2018-04-30',
    'eval_on_model_id': 1,
    'valid_start_date':'2018-06-01',  # must select one of split_date and n_splits, date for spliting train and valid
    'valid_end_date': '2018-06-30',
    'n_splits': 3,  # n_splits for cross validation
}

model, eval_df = train(**params)

# %%
eval_fault_df = eval_df[eval_df.prediction == 1]
mask = eval_fault_df['prediction'] == eval_fault_df['tag']
len(eval_fault_df[eval_fault_df.tag == 1])

# %%
# train
model_params = {
    "objective": "binary",
    "boosting": 'gbdt',
    "learning_rate": 0.001,
    "scale_pos_weight": 25,
    #                 "is_unbalance": True,
    "num_leaves": 32,
    "metric": ["auc"],
    "subsample": 0.8,
    "colsample_bytree": 0.6,
    "num_threads": 10,
    "lambda_l2": 0.8,
    "lambda_l1": 0.8,
    "random_state": 2019,
    "min_data_in_leaf": 80,
    "num_boost_round": 100,
    "device": 'cpu',
}  # 'cpu','gpu'
#                 "gpu_device_id":'2
#                 "max_bin":255}

params = {
    'model_params': model_params,
    'model_name': 'lgb',
    'train_fe_filename': 'train_fe_df_02_01_raw.h5',
    'is_eval': False,
    'is_standard': True,
    'train_start_date': '2018-02-01',
    'train_end_date': '2018-06-30',
}

model, scaler = train(**params)

# %%
# predict 
params = {'model_name': 'lgb',
          'test_fe_filename': 'test_fe_df_02_01_raw.h5', 
          'is_standard': True,
          'pred_on_model_id':1,
          'scaler':scaler,
          'test_month':8,
            }

ret, submission_df = predict(**params)

# %%
submission_df.head()

# %%
# check the distribution of test set
# test_fe_df = pd.read_hdf(os.path.join(conf.DATA_DIR, 'test_fe_df.h5'))
# train_fe_df = pd.read_hdf(os.path.join(conf.DATA_DIR, 'train_fe_df.h5'))
# _, cate_cols, cont_cols, _ = check_columns(train_fe_df.dtypes.to_dict())
# test_fe_df = test_fe_df[cate_cols + cont_cols]
# valid_fe_df = train_fe_df[train_fe_df.dt>=split_date][cate_cols + cont_cols]
# train_fe_df = train_fe_df[train_fe_df.dt<split_date][cate_cols + cont_cols]

# %%
# %%time
# proto = GenericFeatureStatisticsGenerator().ProtoFromDataFrames([{'name': 'test', 'table': test_fe_df},
#                                                                 {'name':'train','table':train_fe_df},
#                                                                 {'name':'valid','table':valid_fe_df}])
# protostr = base64.b64encode(proto.SerializeToString()).decode("utf-8")

# %%
# HTML_TEMPLATE = """
#         <script src="https://cdnjs.cloudflare.com/ajax/libs/webcomponentsjs/1.3.3/webcomponents-lite.js"></script>
#         <link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/1.0.0/facets-dist/facets-jupyter.html" >
#         <facets-overview id="elem"></facets-overview>
#         <script>
#           document.querySelector("#elem").protoInput = "{protostr}";
#         </script>"""
# html = HTML_TEMPLATE.format(protostr=protostr)
# display(HTML(html))
